# %%
from os.path import join, expandvars
from glob import glob

from qiime.util import count_seqs
import pandas as pd

# %%
project_dir = expandvars("$HOME/data/short-read-tax-assignment")
data_dir = join(project_dir, "data")

# %%
fasta_fps = glob(join(data_dir, 'mock-community', '*', 'rep_set.fna'))

data = []
for fp in fasta_fps:
    fields = fp.split('/')
    data_set = fields[-2]
    seq_count, mean_length, std_length = count_seqs(fp)
    data.append([data_set, seq_count, mean_length, std_length])

df = pd.DataFrame(data, columns=['Dataset', 'Sequence count', 'Mean sequence length', 'Standard deviation sequence length'])
df.sort('Dataset')
# Out:
#   Dataset  Sequence count  Mean sequence length  \
# 9      B1            1569             98.621415
# 0      B2            3545            149.989845
# 4      B3              70            192.414286
# 7      B4           13852            150.997329
# 5      B5            7422            235.707895
# 3      B6            4915             92.126755
# 1      B7            2106             98.529915
# 2      B8            2186             97.685270
# 8      F1              94             97.414894
# 6      F2             145             95.579310
#
#    Standard deviation sequence length
# 9                            6.299267
# 0                            0.604551
# 4                            2.964036
# 7                            0.314362
# 5                           17.829497
# 3                            8.404354
# 1                            4.472487
# 2                            4.947828
# 8                            6.536981
# 6                            7.074645

# %%
fasta_fps = glob(join(data_dir, 'simulated-community', '*', 'rep_set.fna'))

data = []
for fp in fasta_fps:
    fields = fp.split('/')
    data_set = fields[-2]
    seq_count, mean_length, std_length = count_seqs(fp)
    data.append([data_set, seq_count, mean_length, std_length])

df = pd.DataFrame(data, columns=['Dataset', 'Sequence count', 'Mean sequence length', 'Standard deviation sequence length'])
df.sort('Dataset')
# Out:
#      Dataset  Sequence count  Mean sequence length  \
# 1   B1-iter0            9983            302.804568
# 13  B1-iter1            9818            301.616623
# 7   B1-iter2            9874            302.437513
# 2   B1-iter3            9785            302.619724
# 5   B1-iter4            9808            303.111847
# 15  B2-iter0            9750             99.995487
# 18  B2-iter1            9849             99.980100
# 4   B2-iter2            9850             99.980102
# 11  B2-iter3            9815             99.985634
# 16  B2-iter4            9978             99.970435
# 14  F1-iter0            2078            223.153032
# 6   F1-iter1            2076            223.349229
# 0   F1-iter2            1942            223.923790
# 12  F1-iter3            2059            223.295289
# 19  F1-iter4            2052            224.764620
# 8   F2-iter0            2044             95.110568
# 10  F2-iter1            2086             95.406520
# 17  F2-iter2            1989             96.076420
# 9   F2-iter3            2024             95.201581
# 3   F2-iter4            2001             93.942529
#
#     Standard deviation sequence length
# 1                            88.869502
# 13                           84.223041
# 7                            87.613960
# 2                            88.376050
# 5                            89.845702
# 15                            0.445582
# 18                            1.396444
# 4                             1.396373
# 11                            1.075024
# 16                            1.704882
# 14                          114.433364
# 6                           118.296470
# 0                           133.617047
# 12                          119.590061
# 19                          123.799025
# 8                            20.842375
# 10                           20.100100
# 17                           18.631193
# 9                            20.500142
# 3                            23.092024
